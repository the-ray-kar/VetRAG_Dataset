# %%
import json
from pydantic_ai import Agent
from pydantic import BaseModel, Field
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
#Get all the text files from ChaptersCleaned directory
import os
def get_text_files(directory):
    return [f for f in os.listdir(directory) if f.endswith('.txt')]
directory = 'ChaptersCleaned'
text_files = get_text_files(directory)

# %%
#Read all the text files and create a dictionary
documents = {}
for file in text_files:
    with open(os.path.join(directory, file), 'r', encoding='utf-8') as f:
        documents[file] = f.read()

# %%
#Get number of words in each document
def get_word_count(text):
    return len(text.split())
word_counts = {file: get_word_count(text) for file, text in documents.items()}
#Print the word counts
for file, count in word_counts.items():
    print(f"{file}: {count} words","Approx llm token count:", count*4/3)


#Total approx token count
total_tokens = sum(word_counts.values()) * 4 / 3
print(f"Total approx token count: {total_tokens}")
# Out:
# everything_about_dogs_administering_medicine.txt: 1917 words Approx llm token count: 2556.0
# everything_about_dogs_breeding.txt: 7372 words Approx llm token count: 9829.333333333334
# everything_about_dogs_diseases.txt: 78952 words Approx llm token count: 105269.33333333333
# everything_about_dogs_distemper.txt: 12921 words Approx llm token count: 17228.0
# everything_about_dogs_dog_papers.txt: 214 words Approx llm token count: 285.3333333333333
# everything_about_dogs_drugs.txt: 2132 words Approx llm token count: 2842.6666666666665
# everything_about_dogs_feeding.txt: 4087 words Approx llm token count: 5449.333333333333
# everything_about_dogs_hydrophobia.txt: 16746 words Approx llm token count: 22328.0
# everything_about_dogs_medicle_terms.txt: 787 words Approx llm token count: 1049.3333333333333
# everything_about_dogs_start_note.txt: 2104 words Approx llm token count: 2805.3333333333335
# Total approx token count: 169642.66666666666

# %%
#Create an agent which takes in the text document and tells what the document is about in points

#Create the data model for the agent
class DocumentSummary(BaseModel):
    summary: str = Field(description="Summary of the document in points")

system_prompt = """You are a helpful agent that summarizes documents. 
You will be given a document and you need to summarize it in points.
Make sure to include the document name in the summary.  
The summary should be concise and to the point. This summary would be used for Agentic RAG which will be used to answer questions about the document."""

#Create the agent
summary_agent = Agent(
    model="google-gla:gemini-2.0-flash",
    output_type=DocumentSummary,
    system_prompt=system_prompt
)

# %%
import asyncio
#Iterate every document and take first 8000 words approx and send it to the agent and store the summary
summarys = {}
for file, text in documents.items():
    print(f"Processing file: {file} with approx {len(text.split())} words")
    prompt = f"Summarize the following document in points:\n\n{file}\n\n{text}\n\nMake sure to include the document name in the summary."
    #Get the summary from the agent
    while True:
        try:
            result = await summary_agent.run(user_prompt=prompt)
            break  # Exit the loop if the run is successful
        except Exception as e:
            print(f"Error occurred: {e}. Retrying in 2 seconds...")
            await asyncio.sleep(2)  # Non-blocking sleep

            if "exhausted" in str(e).lower():
                print("Waiting for 120 seconds before retrying...")
                #Start a stream timer
                await asyncio.sleep(120)  # Wait for 120 seconds before retrying
                print("Resuming after waiting for 120 seconds.")

    summarys[file] = result.output.summary
# Out:
# Processing file: everything_about_dogs_administering_medicine.txt with approx 1917 words
# Processing file: everything_about_dogs_breeding.txt with approx 7372 words
# Processing file: everything_about_dogs_diseases.txt with approx 78952 words
# Processing file: everything_about_dogs_distemper.txt with approx 12921 words
# Processing file: everything_about_dogs_dog_papers.txt with approx 214 words
# Processing file: everything_about_dogs_drugs.txt with approx 2132 words
# Processing file: everything_about_dogs_feeding.txt with approx 4087 words
# Processing file: everything_about_dogs_hydrophobia.txt with approx 16746 words
# Processing file: everything_about_dogs_medicle_terms.txt with approx 787 words
# Processing file: everything_about_dogs_start_note.txt with approx 2104 words

# %%
for file, summary in summarys.items():
    print(f"Summary for {file}:\n{summary}\n")
# Out:
# Summary for everything_about_dogs_administering_medicine.txt:
# Here is a summary of the document everything_about_dogs_administering_medicine.txt in points:
#
# *   The document provides guidance on administering medicine to dogs, emphasizing the importance of kindness and strategy.
# *   It suggests tricking dogs into taking medicine naturally whenever possible and using force only when necessary.
# *   Different methods are described for giving pills, liquids, and powders, including hiding pills in food, using gelatine capsules, and mixing powders with butter or syrup.
# *   The document also discusses the use of injections, emphasizing the importance of using a rubber syringe.
# *   It highlights the differences in how drugs affect dogs compared to humans, noting that some common substances like salt and castor oil have different effects on dogs.
# *   The document advises caution with certain drugs like chloroform, strychnine, and mercury, and suggests that they should only be administered by an expert.
# *   It recommends using hypodermic injections of alkaloidal solutions as the most prompt, efficient, and reliable method of administration.
# *   The importance of antisepsis when treating wounds is also mentioned, along with a warning about the danger of dogs licking the dressing.
# *   The document provides tips for applying remedies to the eyes, ears, and skin, as well as for giving rectal injections.
# *   It notes that drugs act more powerfully on an empty stomach and recommends giving irritating remedies after feeding.
#
# Summary for everything_about_dogs_breeding.txt:
# Here is a summary of the document "everything_about_dogs_breeding.txt" in points:
#
# *   Bitches usually come into season twice a year, and breeding during the first oestrum should be considered based on breed and maturity, generally waiting until at least 18 months for larger breeds.
# *   Breeding every other period is recommended to avoid excessive strain on the bitch, which can lead to weaker litters.
# *   Signs of coming into season include bleeding, and readiness for breeding typically occurs between the tenth and twelfth day from the start of bleeding, though this can vary.
# *   Gestation lasts around 63-64 days, with early spring being the best time for mating.
# *   Proper exercise and a nutritious diet are crucial before and during pregnancy.
# *   Mild laxatives may be beneficial before whelping.
# *   One service is usually sufficient, but a second service after 24 hours is advisable.
# *   After mating, provide a quiet environment, regulated exercise, and avoid overly strenuous activity.
# *   Increase food intake during the last five to six weeks of pregnancy, focusing on protein and soft foods.
# *   Prepare a warm, secluded whelping area with good ventilation and a secure carpet.
# *   Avoid disturbing the bitch during whelping unless complications arise.
# *   Veterinary assistance is crucial for difficult births.
# *   Ensure adequate milk supply; supplement with Spratt's Puppy Food if necessary.
# *   Weaning should start around six to seven weeks, gradually separating the bitch and introducing milk-based and solid foods.
# *   Preventative measures should be taken against worms and gastro-intestinal issues.
# *   Dr. A.J. Sewell's advice includes using forceps or a crochet for difficult head presentations and avoiding hot baths during labor.
# *   Proper care after whelping involves providing fresh bedding, warm milk, and attention to the bitch's hygiene and bowel movements.
# *   Mammary glands need monitoring for inflammation and abscesses.
# *   Parturient eclampsia can be treated with bromide of potassium or hydrated chloral.
# *   Maintain a clean whelping environment to avoid flies, and provide fresh air, exercise, and good food for the puppies.
#
# Summary for everything_about_dogs_diseases.txt:
# Here is a summary of the document "everything_about_dogs_diseases.txt" in points:
#
# *   **Asthma:** Common in house pets, especially toy dogs overfed and lacking exercise. Symptoms include coughing, breathing difficulty, and wheezing. Treatment involves diet changes and medication. Inhalations of thorn apple smoke, tar, resin, or creosote fumes can provide relief. Tumors in the respiratory tract may cause an incurable asthmatic form.
# *   **Abscess:** Pus formation due to blows, accidents, or inflammation. Treatment involves hot fomentations, opening the abscess, and cleaning with warm water or Peroxyde of Hydrogen. Peri-rectal abscesses are common in distemper cases.
# *   **Abortion:** Premature expulsion of the foetus. Causes include poor diet, overfeeding, severe exercise, and drinking foul water. Prevention involves proper health care and selecting healthy breeding bitches.
# *   **Anaemia:** Poverty of blood, indicated by pale mucous membranes, weakness, and depression. Causes include poor food, excessive demands on stud dogs, and worms. Treatment involves nourishing foods, tonics, and a warm environment.
# *   **Asphyxia:** Inability to breathe due to near drowning. Treatment involves removing water from lungs, artificial respiration, and stimulants.
# *   **Bladder Inflammation:** Painful urination in small quantities. Caused by blows, exposure to cold, or certain medications. Treatment includes purgatives, clysters, and benzoic acid.
# *   **Bladder Paralysis:** Inability to urinate, often due to over-distension. Treatment involves hot fomentations, catheterization, and pressure on the bladder.
# *   **Bleeding From the Stomach:** Vomiting of blood, which may be caused by injury. Treatment involves resting the stomach and administering medication.
# *   **Boils:** Painful swellings indicating weakness or plethora. Treatment involves diet reform, bathing, exercise, and opening the boils with an antiseptic.
# *   **Bites:** Wash the wound, remove blood, and apply friar's balsam or tincture of myrrh. Tincture of iodine and Unguentine are recommended. Suck the bite to remove poison.
# *   **Inflammation of Bowels (Enteritis; Peritonitis):** Dangerous disease caused by improper diet, exposure, or injury. Symptoms include fever, anxiety, and abdominal pain. Treatment involves enemas, castor oil, and pain relief.
# *   **Back Stiffness:** Caused by old age, rheumatism, or injury. Treatment includes rest, liniments, and light diet.
# *   **Bad Breath:** Caused by disordered stomach, teeth, or lung issues. Treatment involves addressing the underlying cause and cleaning teeth.
# *   **Balanatis:** Purulent discharge from the prepuce. Treatment includes regulating diet, cleaning the area, and medication.
# *   **Bruises:** Bathe with warm water and apply liniment.
# *   **Burns and Scalds:** Apply linseed oil and lime water or boracic ointment.
# *   **Baldness:** Result of inbreeding or debility. Treat with ointment or skin remedy.
# *   **Blain:** Vesicular swelling of the tongue, also known as malignant sore mouth. Treat with tincture of sanquinaria canadensis and bichloride of mercury tablets.
# *   **Brain Inflammation (Meningitis):** Inflammation of the brain membranes. Symptoms include drowsiness and spasms. Requires veterinary care.
# *   **Blisters:** See general remarks under heading of Medical.
#
# Summary for everything_about_dogs_distemper.txt:
# Here's a summary of the document everything_about_dogs_distemper.txt in points:
#
# *   Distemper is a major concern for dog breeders, causing more deaths than most other issues besides worms.
# *   It's crucial to study distemper before it appears in your dogs to be prepared.
# *   Distemper doesn't have to be fatal; many dogs recover with proper care.
# *   Early signs of distemper should be addressed immediately by isolating the affected dog, disinfecting kennels, and using remedies like Clayton's few clays or Distemperine.
# *   A homemade remedy involves placing sliced raw onions in a stocking leg around the dog's neck.
# *   Diet during distemper should avoid solid meats and focus on easily digestible foods like gruels, broths, and beef tea.
# *   Maintaining the dog's appetite is critical; try coaxing them with delicacies like quail or chicken giblet gravy.
# *   After distemper, use tonics like Eberhart's Tonic Pills to help the dog recover.
# *   Frequent bedding changes are essential during sickness.
# *   Consider preventative remedies for dogs at shows to avoid contracting distemper.
# *   Distemper is compared to measles in humans due to similar symptoms and transmission.
# *   The germ theory is the accepted cause of distemper, though some believe poor conditions can contribute.
# *   Distemper is transmissible to other animals like cats and wolves but not to humans.
# *   Infected dogs should be isolated, and hygiene should be maintained to prevent the spread of the disease.
# *   Symptoms include fever, cough, loss of appetite, and discharge from the eyes and nose.
# *   Complications include pneumonia, epileptic fits, vomiting, and dysentery.
# *   Treatment focuses on warm quarters, good nursing, and judicious medical care.
# *   Hyposulphite of soda and quinine are useful drugs in treating distemper.
# *   Avoid exposing convalescing dogs to cold to prevent relapse.
# *   Shows are a major source of spreading distemper, so take precautions.
# *   Early symptoms include a rise in temperature, dullness, and loss of appetite.
# *   Distemper is a germ that finds ready cultivation in unhealthy conditions that result from worms.
# *   Treatment should be started early, and the patient should be isolated.
# *   In treatment, the writer does not believe in the speedy use of any medicine; the less used the better you are off, and the clog, generally.
# *   Give pepsin, bismuth, and charcoal tablets to soothe the stomach.
# *   If the patient is well advanced in the purulent mucus discharge or acute bronchial stage, before you get at him, which is usual in the experience of amateurs, begin at once and conform rigidly to treat as heretofore suggested, adding the possible help of some distemper medicine.
# *   In severe cases, consider inserting a seton to drain poisonous accumulations.
#
# Summary for everything_about_dogs_dog_papers.txt:
# Here is a summary of the document everything_about_dogs_dog_papers.txt in points:
#
# *   The document lists several dog-related publications.
# *   It mentions "Field and Fancy" (weekly) and "American Fancier" (weekly, edited by Harry W. Lacy).
# *   It recommends "Dogdom" (monthly) as a good investment for dog owners.
# *   It includes "The Dog Fancier" (monthly) and "The American Field" (weekly), specializing in hunting dogs.
# *   It also mentions "Dog World" (monthly) and "Hounds and Hunting" (for Beagle and Hound enthusiasts).
# *   The author offers to handle subscriptions for these publications.
#
# Summary for everything_about_dogs_drugs.txt:
# Here is a summary of the document everything_about_dogs_drugs.txt:
#
# *   **Acetic Acid:** Used in cooling lotions for swellings and bruises. The formula includes sal ammoniac, strong acetic acid, boiling water, and methylated spirit.
# *   **Gallic Acid:** An astringent and styptic, useful in diabetes and internal hemorrhage. Can be administered in styptic powders with alum and opium.
# *   **Aconite:** Used in liniments for rheumatism and in distemper mixtures for nervous excitement. Administer with caution.
# *   **Aloes:** A safe purgative for dogs, but start with a small dose. Often combined with other purgatives in aperient pills.
# *   **Alum:** An astringent used in diabetes, internal hemorrhage, and diarrhea. Burnt alum is a mild caustic for fungus growths.
# *   **Ammonia, Aromatic Spirits of:** A stimulant and antacid useful in colic and depression. Dilute before administering.
# *   **Ammonia, Muriate:** (Sal ammoniac) - See Acetic acid.
# *   **Ammonia, Solution of Acetate of:** (Mindererus' Spirit) - Given in febrile and inflammatory disorders like distemper and pneumonia. Used in distemper mixtures.
# *   **Ammonia, Strong Liquid:** Used as a blister. Diluted, it forms spirit of hartshorn for liniments for sprains and bruises.
# *   **Antimonial Powder:** (James' Powder) - A febrifuge and diaphoretic, preferred over tartar emetic.
# *   **Antimony, Tartarated:** (Tartar Emetic) - An emetic used with caution for distemper, jaundice and poisoning.
# *   **Arnica, Tincture of:** Used externally as a stimulant for sprains, bruises, rheumatic lameness and tumors. Dilute with water.
# *   **Arsenic, Fowler's Solution of:** An alterative for mange and skin diseases. Give on a full stomach and watch for adverse reactions.
# *   **Belladonna:** A powerful narcotic and sedative, use with caution.
# *   **Benzoin, Tincture of:** (Friar's Balsam) - For cuts, tears, and bites to stop bleeding. Also given in chronic coughs.
# *   **Bismuth:** The subnitrate form soothes stomach disorders and diarrhea.
# *   **Bromide of Potassium:** Useful in epileptic fits and to allay excitement, but can have a debilitating effect.
# *   **Buckthorn:** (Syrup of) - A purgative for dogs, but quality can vary.
# *   **Calomel:** An uncertain and unsafe medicine for dogs; podophyllin is a safer alternative for liver issues.
# *   **Camphor:** A calmative and antispasmodic for excitement, restlessness and diarrhea.
# *   **Carren Oil:** For scalds or burns, made from linseed oil and lime water.
# *   **Castor Oil:** A purgative; avoid very large doses.
# *   **Cayenne Pepper:** A stimulant and stomachic.
# *   **Chalk, prepared:** An antacid for diarrhea.
# *   **Chloral Hydrate:** An antispasmodic and soporific for fits and pain; larger doses induce sleep.
# *   **Chloroform:** Used as an anesthetic in painful operations, also an anodyne and antispasmodic in colic.
# *   **Cinchona, or Peruvian Bark:** A tonic, especially useful after distemper and other lowering diseases.
# *   **Cod Liver Oil:** For debility, emaciation, and chronic respiratory diseases; good for ricketty dogs but avoid giving to strong, growing pups of larger breeds.
# *   **Copper, Sulphate of:** (Blue Stone) - A mild caustic externally, astringent and tonic internally. Can cause vomiting.
# *   **Cream of Tartar:** A cooling laxative and diuretic.
# *   **Dandelion:** For jaundice and other liver affections.
# *   **Epsom Salts:** A purgative.
# *   **Ergot of Rye:** Useful in cases of protracted parturition.
# *   **Ether, Spirit of Nitrous:** (Sweet Spirit of Nitre) - A diaphoretic and diuretic, given in distemper, fevers, influenza, etc.
#
# Summary for everything_about_dogs_feeding.txt:
# Here is a summary of the document everything_about_dogs_feeding.txt in points:
#
# *   Dogs over six months old should only be fed twice a day at regular times.
# *   Dogs should eat plain food, including cooked meat (beef or mutton) daily, but avoid veal and pork.
# *   Cooked liver can be given once a week as a treat and laxative, but not as a main food.
# *   Buttermilk is better than sweet milk, especially in the summer.
# *   For adult dogs, breakfast can consist of Spratt's Patent Dog Cakes or Maltoid Milk-Bone, fed dry.
# *   Supper should be the main meal, consisting of cooked meat (beef, mutton, or sheep/calves' head) mixed with Conner's Cooked Dog Food (a cereal).
# *   Bones, especially large ones, are good for dogs to chew on after supper, but chicken and small bones should be avoided due to the risk of slivers.
# *   Vegetables like carrots, beets, and rice can be added to the soup for variety.
# *   Hard feed like bones or biscuits is important for dental health.
# *   Avoid feeding dogs candy, cake, or sweet/greasy foods.
# *   Keep clean, fresh water available, especially in summer.
# *   For toy dogs, avoid sloppy, sweet foods and opt for a dry, hard diet.
# *   Hunting dogs thrive on a mixed diet of meat, grain, and vegetables, adjusting the proportions based on the dog's condition and activity level.
# *   Puppies should be gradually weaned onto a diet of boiled/scalded milk with bread, potatoes, gravy, soups with vegetables, and chicken gravy.
# *   Puppies should be fed four times a day, gradually reducing to three meals, and then transitioned to the adult dog diet around six months old.
# *   Avoid feeding puppies raw milk.
# *   Burn or dispose of chicken, turkey, and fish bones to prevent choking or internal damage.
#
# Summary for everything_about_dogs_hydrophobia.txt:
# Here are the summary points from the document everything_about_dogs_hydrophobia.txt:
#
# *   The author expresses strong disbelief in hydrophobia, citing personal experiences of being bitten by dogs displaying symptoms of the disease without contracting it.
# *   The author criticizes the overuse of the term "germs" by doctors and veterinarians and questions the existence of hydrophobia germs.
# *   The author suggests a simple method of sucking the blood from a dog bite immediately and spitting it out, or using Peroxyde of Hydrogen, to prevent blood poisoning.
# *   The author argues that fear and panic contribute to the belief and manifestation of hydrophobia symptoms.
# *   The author advises against killing a dog that has bitten someone, suggesting instead that the dog be confined and observed to determine if it was truly mad.
# *   The author presents interviews with Prof. Al. G. Eberhart, who shares similar views, stating that he has been bitten numerous times by dogs, including those diagnosed with rabies, without contracting the disease.
# *   The document includes an editorial from the St. Louis Republic discussing Prof. Eberhart's views and questioning the existence of poisonous rabies.
# *   The document presents arguments against muzzling dogs and criticizes the Pasteur Institute for keeping the public in an unhealthy state of mind regarding hydrophobia.
# *   The views of Dr. H. Clay Glover, who claims that the mad dog scare is a myth, are presented.
# *   The document differentiates rabies from apoplexy and epilepsy, noting that a slight derangement of the dog's nervous system is often mistaken for rabies symptoms.
# *   The document also presents the views of Prof. Edward C. Spitzka, who declares the Pasteur rabies theory and treatment a humbug and rabies to be a hoax.
# *   Finally, the document includes Hugh Dalziel's treatise on hydrophobia.
#
# Summary for everything_about_dogs_medicle_terms.txt:
# Here is a summary of the document everything_about_dogs_medicle_terms.txt:
#
# - Alteratives: Medicines that gradually bring about a healthy state.
# - Anesthetics: Drugs that deprive of sensation or feeling.
# - Anodynes: Drugs that assuage pain.
# - Antiseptics: Medicines that resist or check putrefaction.
# - Antispasmodics: Medicine that overcomes inordinate muscular action.
# - Astringents: Drugs that contract muscular fiber and check diarrhea, hemorrhage and diabetes.
# - Blisters: Agents used as counter irritants for internal inflammation.
# - Cordials: Medicines that increase strength and stimulate the stomach.
# - Carminatives: Medicines that expel wind.
# - Cathartics, Purgatives, Aperients: Medicines to cause discharges, cleansing stomach and bowels.
# - Caustics: Agents that destroy or decompose parts to which they are applied.
# - Demulcents: Agents to soften effects of irritants, by sheathing the surface.
# - Diaphoretics: Medicines to produce sweating.
# - Diuretics: Remedies which increase discharge of urine.
# - Emetics: Agents used to produce vomiting.
# - Emollients: Agents that soften or relax the parts applied to.
# - Narcotics: Medicines to produce sleep and relieve pain.
# - Stimulants: Medicine and liquors used to produce immediate but temporary increase of strength.
# - Stomachics and Tonics: Medicines to excite and strengthen the stomach.
# - Vermifuge: Medicines to destroy or expel worms.
# - Clysters or Enemas: Agents mostly in liquid form, administered for various purposes such as softening and removal of hardened feces, allaying spasm or colic, destruction of worms, checking diarrhea, or nourishing the body.
#
# Summary for everything_about_dogs_start_note.txt:
# Here's a summary of the document "everything_about_dogs_start_note.txt" in points:
#
# *   The author expresses the immense effort put into writing the third and final edition of "EVERYTHING ABOUT DOGS", driven by a sense of duty to dogs and a desire to share valuable knowledge with dog owners.
# *   The author emphasizes the book's unique purpose: to benefit dogs, drawing from a lifetime of experience and collected wisdom.
# *   The author contrasts the loyalty of dogs with the fickleness of humans, highlighting the unconditional love and faithfulness of dogs.
# *   The author shares personal anecdotes, including making provisions for his dogs' care in his will and advocating for any kind of dog ownership to provide happiness to the animal.
# *   The author addresses the issue of homeless dogs, attributing it to irresponsible owners and advocating for stricter laws regarding uncontrolled breeding.
# *   The author reflects on the success of previous editions, expressing gratitude for the positive feedback received.
# *   The author provides guidance on responsible dog ownership, including proper care, exercise, training, and discipline.
# *   The author advises against excessive use of sulphur for dogs and suggests alternatives like providing grass for dogs in flats.
# *   The author dedicates the book to dogs and their owners.
